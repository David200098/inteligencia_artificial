# %% [markdown]
# # EDA Pokemon y algo más...

# %%
# Data manipulation libraries
import numpy as np 
import pandas as pd 

# Data visualisation 
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# Web scraping 
from bs4 import BeautifulSoup, Comment
from requests import get

## Reading the data
pokemon = pd.read_csv('Pokemon.csv')

# %%
print(pokemon.head())
print(pokemon.info())
# Out:
#    #                   Name Type 1  ... Speed  Generation  Legendary
# 0  1              Bulbasaur  Grass  ...    45           1      False
# 1  2                Ivysaur  Grass  ...    60           1      False
# 2  3               Venusaur  Grass  ...    80           1      False
# 3  3  VenusaurMega Venusaur  Grass  ...    80           1      False
# 4  4             Charmander   Fire  ...    65           1      False
#
# [5 rows x 13 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB
# None

# %%
pokemon
# Out:
#        #                   Name   Type 1  ... Speed  Generation  Legendary
# 0      1              Bulbasaur    Grass  ...    45           1      False
# 1      2                Ivysaur    Grass  ...    60           1      False
# 2      3               Venusaur    Grass  ...    80           1      False
# 3      3  VenusaurMega Venusaur    Grass  ...    80           1      False
# 4      4             Charmander     Fire  ...    65           1      False
# ..   ...                    ...      ...  ...   ...         ...        ...
# 795  719                Diancie     Rock  ...    50           6       True
# 796  719    DiancieMega Diancie     Rock  ...   110           6       True
# 797  720    HoopaHoopa Confined  Psychic  ...    70           6       True
# 798  720     HoopaHoopa Unbound  Psychic  ...    80           6       True
# 799  721              Volcanion     Fire  ...    70           6       True
#
# [800 rows x 13 columns]

# %%
# Desechar #
pokemon.drop(['#'], axis = 'columns', inplace = True)

# Sólo trabajaremos con la generación 3,4
my_pokemon = pokemon[pokemon.Generation.isin([3, 4])].copy()
my_pokemon.Generation.unique()
my_pokemon.shape
# Out:
# (281, 12)

# %%
print('There are ',my_pokemon.duplicated('Name').sum(), 'duplicated names in the dataset, so it must be something else\n')
print(my_pokemon.loc[(my_pokemon.Generation == 3) & (my_pokemon.Legendary == True), 'Name'],  '''\nAha! We didn't have MEGA stuff back in my day. Let's exclude those\n''')
# Out:
# There are  0 duplicated names in the dataset, so it must be something else
#
# 414                 Regirock
# 415                   Regice
# 416                Registeel
# 417                   Latias
# 418        LatiasMega Latias
# 419                   Latios
# 420        LatiosMega Latios
# 421                   Kyogre
# 422      KyogrePrimal Kyogre
# 423                  Groudon
# 424    GroudonPrimal Groudon
# 425                 Rayquaza
# 426    RayquazaMega Rayquaza
# 427                  Jirachi
# 428       DeoxysNormal Forme
# 429       DeoxysAttack Forme
# 430      DeoxysDefense Forme
# 431        DeoxysSpeed Forme
# Name: Name, dtype: object
# Aha! We didn't have MEGA stuff back in my day. Let's exclude those

# %%
mega_filter = (my_pokemon.Name.str.contains('Mega ')) #Put a space there to exclude meganium which is a legit second generation pokemon
my_pokemon = my_pokemon[~mega_filter]
print(my_pokemon.groupby('Generation').size(),  '\nOk now everything matches my expectations!')
# Out:
# Generation
# 3    140
# 4    116
# dtype: int64
# Ok now everything matches my expectations!

# %%
def my_pairgrid(input_df):
    mpl.rcParams["axes.labelsize"] = 20 #Increases the axis titles and the legend size
    g = sns.PairGrid(input_df, vars=['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed'])
    g = g.map_diag(sns.kdeplot, shade=True)
    g = g.map_lower(sns.regplot, scatter_kws={'alpha':0.3})
    g.hue_vals = input_df["Legendary"]
    g.hue_names = input_df["Legendary"].unique()
    g.palette = sns.color_palette("Set2", len(g.hue_names))
    g = g.map_upper(sns.scatterplot).add_legend(title='Legendary', fontsize= 14)
    return(g)
_ = my_pairgrid(my_pokemon)

# %%
my_pokemon
# Out:
#                   Name  Type 1    Type 2  ...  Speed  Generation  Legendary
# 272            Treecko   Grass       NaN  ...     70           3      False
# 273            Grovyle   Grass       NaN  ...     95           3      False
# 274           Sceptile   Grass       NaN  ...    120           3      False
# 276            Torchic    Fire       NaN  ...     45           3      False
# 277          Combusken    Fire  Fighting  ...     55           3      False
# ..                 ...     ...       ...  ...    ...         ...        ...
# 548            Manaphy   Water       NaN  ...    100           4      False
# 549            Darkrai    Dark       NaN  ...    125           4       True
# 550  ShayminLand Forme   Grass       NaN  ...    100           4       True
# 551   ShayminSky Forme   Grass    Flying  ...    127           4       True
# 552             Arceus  Normal       NaN  ...    120           4       True
#
# [256 rows x 12 columns]

# %%
my_corr = my_pokemon.loc[:, 'HP':'Speed'].corr() 
mask = np.zeros_like(my_corr) 
mask[np.triu_indices_from(mask)] = True ## This part is to blank out the upper diagonal
with sns.axes_style("white"):
     ax = sns.heatmap(my_corr, mask=mask, square=True, cmap=sns.color_palette("Blues"), vmax=np.max(np.sort(my_corr.values)[:,-2]), linewidths=0.3)

# %%
sns.reset_defaults()
plt.figure(figsize=(16,12))
g = sns.swarmplot(x='HP', y='Type 1', hue = 'Generation', data=my_pokemon)
g.yaxis.label.set_visible(False)
g.set_title('HP broken down by Type and Generation')
_ = g.annotate('These are Chansey and Blissey', xy=(253, 3.5), xytext = (250, 2), fontsize = 12, arrowprops=dict(facecolor='black') )
_ = g.annotate('Wooooobbufet', xy=(190, 9.5), xytext = (191, 8.5), fontsize = 12, arrowprops=dict(facecolor='green'))
g.title.set_fontsize(20)
g.xaxis.label.set_fontsize(18)
g.tick_params(axis='x', labelsize=16)
g.tick_params(axis='y', labelsize=16)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1296: UserWarning:
#
# 6.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.

# %%
my_pokemon.loc[my_pokemon['Type 1'] == "Fairy", 'Type 1'] = 'Normal'
my_pokemon.loc[my_pokemon['Type 2'] == "Fairy", 'Type 2'] = np.nan

# %%
def attr_per_type(input_df, y_attr, hue_attr):
    mpl.rcParams["font.size"] = 18
    f, axes = plt.subplots(2, 3, figsize=(20, 20), sharey=True, sharex=True)
    #f.tight_layout()
    poke_attributes = ['HP', 'Defense', 'Sp. Def', 'Speed', 'Attack', 'Sp. Atk']
    counter = 0
    #axes[0,1].tick_params(labelleft=False)
    for row in range(2):
        for col in range(3):
            sns.boxplot(y = y_attr, x = poke_attributes[counter], data=input_df, ax=axes[row, col], showfliers=False)
            sns.swarmplot(y = y_attr, x = poke_attributes[counter], data=input_df, ax=axes[row, col], hue = hue_attr, palette=['black', 'orange'])
            axes[row, col].set_title(axes[row, col].get_xlabel())
            axes[row, col].xaxis.label.set_visible(False)
            axes[row, col].get_legend().remove()
            counter += 1
            if (col == 0):
                axes[row, col].yaxis.label.set_visible(False)
                continue
            axes[row, col].yaxis.set_visible(False)
    return(f, axes)

# %%
(f, axes) = attr_per_type(my_pokemon, 'Type 1', 'Legendary')
_ = axes[0, 1].annotate('Shuckle the defense \nmonster', xy=(230, 3.2), xytext = (140, 5), arrowprops=dict(facecolor='blue'))
_ = axes[0, 2].annotate('Ho-oh so much \nspecial defence', xy=(154, 1.1), xytext=(150, 2.8), arrowprops=dict(facecolor='red'))
_ = axes[1, 2].annotate('Mewtwo destroyer \nof worlds', xy=(155, 8.8), xytext= (100, 8), arrowprops=dict(facecolor='purple'))
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1296: UserWarning:
#
# 6.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1296: UserWarning:
#
# 5.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1296: UserWarning:
#
# 5.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1296: UserWarning:
#
# 6.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1296: UserWarning:
#
# 6.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.

# %%
poke_url = 'https://pokemondb.net/evolution#evo-g2'
response = get(poke_url) 
html_soup = BeautifulSoup(response.text, 'html.parser') ## Getting the html into python

# %%
infocard = html_soup.find_all('div', {'class' : 'infocard-list-evo'})

# %%
raw = []
for chain in infocard:
    raw.append(([(i, x.find('small').getText(), x.find_all('small')[1].getText(), x.find('a', {'class':'ent-name'}).getText(), ) for i, x in enumerate(list(chain.find_all('span', {'class':'infocard-lg-data text-muted'})), 1)]))

raw[:4] ## Our list contains touple lists with the evolution branch of each pokemon. We keep that in mind for our future processing
# Out:
# [[(1, '#001', 'Grass · Poison', 'Bulbasaur'),
#   (2, '#002', 'Grass · Poison', 'Ivysaur'),
#   (3, '#003', 'Grass · Poison', 'Venusaur')],
#  [(1, '#004', 'Fire', 'Charmander'),
#   (2, '#005', 'Fire', 'Charmeleon'),
#   (3, '#006', 'Fire · Flying', 'Charizard')],
#  [(1, '#007', 'Water', 'Squirtle'),
#   (2, '#008', 'Water', 'Wartortle'),
#   (3, '#009', 'Water', 'Blastoise')],
#  [(1, '#010', 'Bug', 'Caterpie'),
#   (2, '#011', 'Bug', 'Metapod'),
#   (3, '#012', 'Bug · Flying', 'Butterfree')]]

# %%
raw
# Out:
# [[(1, '#001', 'Grass · Poison', 'Bulbasaur'),
#   (2, '#002', 'Grass · Poison', 'Ivysaur'),
#   (3, '#003', 'Grass · Poison', 'Venusaur')],
#  [(1, '#004', 'Fire', 'Charmander'),
#   (2, '#005', 'Fire', 'Charmeleon'),
#   (3, '#006', 'Fire · Flying', 'Charizard')],
#  [(1, '#007', 'Water', 'Squirtle'),
#   (2, '#008', 'Water', 'Wartortle'),
#   (3, '#009', 'Water', 'Blastoise')],
#  [(1, '#010', 'Bug', 'Caterpie'),
#   (2, '#011', 'Bug', 'Metapod'),
#   (3, '#012', 'Bug · Flying', 'Butterfree')],
#  [(1, '#013', 'Bug · Poison', 'Weedle'),
#   (2, '#014', 'Bug · Poison', 'Kakuna'),
#   (3, '#015', 'Bug · Poison', 'Beedrill')],
#  [(1, '#016', 'Normal · Flying', 'Pidgey'),
#   (2, '#017', 'Normal · Flying', 'Pidgeotto'),
#   (3, '#018', 'Normal · Flying', 'Pidgeot')],
#  [(1, '#019', 'Normal', 'Rattata'), (2, '#020', 'Normal', 'Raticate')],
#  [(1, '#019', 'Alolan Rattata', 'Rattata'),
#   (2, '#020', 'Alolan Raticate', 'Raticate')],
#  [(1, '#021', 'Normal · Flying', 'Spearow'),
#   (2, '#022', 'Normal · Flying', 'Fearow')],
#  [(1, '#023', 'Poison', 'Ekans'), (2, '#024', 'Poison', 'Arbok')],
#  [(1, '#172', 'Electric', 'Pichu'),
#   (2, '#025', 'Electric', 'Pikachu'),
#   (3, '#026', 'Electric', 'Raichu'),
#   (4, '#026', 'Alolan Raichu', 'Raichu')],
#  [(1, '#026', 'Electric', 'Raichu')],
#  [(1, '#026', 'Alolan Raichu', 'Raichu')],
#  [(1, '#027', 'Ground', 'Sandshrew'), (2, '#028', 'Ground', 'Sandslash')],
#  [(1, '#027', 'Alolan Sandshrew', 'Sandshrew'),
#   (2, '#028', 'Alolan Sandslash', 'Sandslash')],
#  [(1, '#029', 'Poison', 'Nidoran♀'),
#   (2, '#030', 'Poison', 'Nidorina'),
#   (3, '#031', 'Poison · Ground', 'Nidoqueen')],
#  [(1, '#032', 'Poison', 'Nidoran♂'),
#   (2, '#033', 'Poison', 'Nidorino'),
#   (3, '#034', 'Poison · Ground', 'Nidoking')],
#  [(1, '#173', 'Fairy', 'Cleffa'),
#   (2, '#035', 'Fairy', 'Clefairy'),
#   (3, '#036', 'Fairy', 'Clefable')],
#  [(1, '#037', 'Fire', 'Vulpix'), (2, '#038', 'Fire', 'Ninetales')],
#  [(1, '#037', 'Alolan Vulpix', 'Vulpix'),
#   (2, '#038', 'Alolan Ninetales', 'Ninetales')],
#  [(1, '#174', 'Normal · Fairy', 'Igglybuff'),
#   (2, '#039', 'Normal · Fairy', 'Jigglypuff'),
#   (3, '#040', 'Normal · Fairy', 'Wigglytuff')],
#  [(1, '#041', 'Poison · Flying', 'Zubat'),
#   (2, '#042', 'Poison · Flying', 'Golbat'),
#   (3, '#169', 'Poison · Flying', 'Crobat')],
#  [(1, '#043', 'Grass · Poison', 'Oddish'),
#   (2, '#044', 'Grass · Poison', 'Gloom'),
#   (3, '#045', 'Grass · Poison', 'Vileplume'),
#   (4, '#182', 'Grass', 'Bellossom')],
#  [(1, '#045', 'Grass · Poison', 'Vileplume')],
#  [(1, '#182', 'Grass', 'Bellossom')],
#  [(1, '#046', 'Bug · Grass', 'Paras'), (2, '#047', 'Bug · Grass', 'Parasect')],
#  [(1, '#048', 'Bug · Poison', 'Venonat'),
#   (2, '#049', 'Bug · Poison', 'Venomoth')],
#  [(1, '#050', 'Ground', 'Diglett'), (2, '#051', 'Ground', 'Dugtrio')],
#  [(1, '#050', 'Alolan Diglett', 'Diglett'),
#   (2, '#051', 'Alolan Dugtrio', 'Dugtrio')],
#  [(1, '#052', 'Normal', 'Meowth'), (2, '#053', 'Normal', 'Persian')],
#  [(1, '#052', 'Alolan Meowth', 'Meowth'),
#   (2, '#053', 'Alolan Persian', 'Persian')],
#  [(1, '#052', 'Galarian Meowth', 'Meowth'),
#   (2, '#863', 'Steel', 'Perrserker')],
#  [(1, '#054', 'Water', 'Psyduck'), (2, '#055', 'Water', 'Golduck')],
#  [(1, '#056', 'Fighting', 'Mankey'), (2, '#057', 'Fighting', 'Primeape')],
#  [(1, '#058', 'Fire', 'Growlithe'), (2, '#059', 'Fire', 'Arcanine')],
#  [(1, '#060', 'Water', 'Poliwag'),
#   (2, '#061', 'Water', 'Poliwhirl'),
#   (3, '#062', 'Water · Fighting', 'Poliwrath'),
#   (4, '#186', 'Water', 'Politoed')],
#  [(1, '#062', 'Water · Fighting', 'Poliwrath')],
#  [(1, '#186', 'Water', 'Politoed')],
#  [(1, '#063', 'Psychic', 'Abra'),
#   (2, '#064', 'Psychic', 'Kadabra'),
#   (3, '#065', 'Psychic', 'Alakazam')],
#  [(1, '#066', 'Fighting', 'Machop'),
#   (2, '#067', 'Fighting', 'Machoke'),
#   (3, '#068', 'Fighting', 'Machamp')],
#  [(1, '#069', 'Grass · Poison', 'Bellsprout'),
#   (2, '#070', 'Grass · Poison', 'Weepinbell'),
#   (3, '#071', 'Grass · Poison', 'Victreebel')],
#  [(1, '#072', 'Water · Poison', 'Tentacool'),
#   (2, '#073', 'Water · Poison', 'Tentacruel')],
#  [(1, '#074', 'Rock · Ground', 'Geodude'),
#   (2, '#075', 'Rock · Ground', 'Graveler'),
#   (3, '#076', 'Rock · Ground', 'Golem')],
#  [(1, '#074', 'Alolan Geodude', 'Geodude'),
#   (2, '#075', 'Alolan Graveler', 'Graveler'),
#   (3, '#076', 'Alolan Golem', 'Golem')],
#  [(1, '#077', 'Fire', 'Ponyta'), (2, '#078', 'Fire', 'Rapidash')],
#  [(1, '#077', 'Galarian Ponyta', 'Ponyta'),
#   (2, '#078', 'Galarian Rapidash', 'Rapidash')],
#  [(1, '#079', 'Water · Psychic', 'Slowpoke'),
#   (2, '#080', 'Water · Psychic', 'Slowbro'),
#   (3, '#199', 'Water · Psychic', 'Slowking')],
#  [(1, '#080', 'Water · Psychic', 'Slowbro')],
#  [(1, '#199', 'Water · Psychic', 'Slowking')],
#  [(1, '#079', 'Galarian Slowpoke', 'Slowpoke'),
#   (2, '#080', 'Galarian Slowbro', 'Slowbro'),
#   (3, '#199', 'Galarian Slowking', 'Slowking')],
#  [(1, '#080', 'Galarian Slowbro', 'Slowbro')],
#  [(1, '#199', 'Galarian Slowking', 'Slowking')],
#  [(1, '#081', 'Electric · Steel', 'Magnemite'),
#   (2, '#082', 'Electric · Steel', 'Magneton'),
#   (3, '#462', 'Electric · Steel', 'Magnezone')],
#  [(1, '#084', 'Normal · Flying', 'Doduo'),
#   (2, '#085', 'Normal · Flying', 'Dodrio')],
#  [(1, '#086', 'Water', 'Seel'), (2, '#087', 'Water · Ice', 'Dewgong')],
#  [(1, '#088', 'Poison', 'Grimer'), (2, '#089', 'Poison', 'Muk')],
#  [(1, '#088', 'Alolan Grimer', 'Grimer'), (2, '#089', 'Alolan Muk', 'Muk')],
#  [(1, '#090', 'Water', 'Shellder'), (2, '#091', 'Water · Ice', 'Cloyster')],
#  [(1, '#092', 'Ghost · Poison', 'Gastly'),
#   (2, '#093', 'Ghost · Poison', 'Haunter'),
#   (3, '#094', 'Ghost · Poison', 'Gengar')],
#  [(1, '#095', 'Rock · Ground', 'Onix'),
#   (2, '#208', 'Steel · Ground', 'Steelix')],
#  [(1, '#096', 'Psychic', 'Drowzee'), (2, '#097', 'Psychic', 'Hypno')],
#  [(1, '#098', 'Water', 'Krabby'), (2, '#099', 'Water', 'Kingler')],
#  [(1, '#100', 'Electric', 'Voltorb'), (2, '#101', 'Electric', 'Electrode')],
#  [(1, '#102', 'Grass · Psychic', 'Exeggcute'),
#   (2, '#103', 'Grass · Psychic', 'Exeggutor'),
#   (3, '#103', 'Alolan Exeggutor', 'Exeggutor')],
#  [(1, '#103', 'Grass · Psychic', 'Exeggutor')],
#  [(1, '#103', 'Alolan Exeggutor', 'Exeggutor')],
#  [(1, '#104', 'Ground', 'Cubone'),
#   (2, '#105', 'Ground', 'Marowak'),
#   (3, '#105', 'Alolan Marowak', 'Marowak')],
#  [(1, '#105', 'Ground', 'Marowak')],
#  [(1, '#105', 'Alolan Marowak', 'Marowak')],
#  [(1, '#236', 'Fighting', 'Tyrogue'),
#   (2, '#106', 'Fighting', 'Hitmonlee'),
#   (3, '#107', 'Fighting', 'Hitmonchan'),
#   (4, '#237', 'Fighting', 'Hitmontop')],
#  [(1, '#106', 'Fighting', 'Hitmonlee')],
#  [(1, '#107', 'Fighting', 'Hitmonchan')],
#  [(1, '#237', 'Fighting', 'Hitmontop')],
#  [(1, '#108', 'Normal', 'Lickitung'), (2, '#463', 'Normal', 'Lickilicky')],
#  [(1, '#109', 'Poison', 'Koffing'), (2, '#110', 'Poison', 'Weezing')],
#  [(1, '#109', 'Poison', 'Koffing'),
#   (2, '#110', 'Galarian Weezing', 'Weezing')],
#  [(1, '#111', 'Ground · Rock', 'Rhyhorn'),
#   (2, '#112', 'Ground · Rock', 'Rhydon'),
#   (3, '#464', 'Ground · Rock', 'Rhyperior')],
#  [(1, '#440', 'Normal', 'Happiny'),
#   (2, '#113', 'Normal', 'Chansey'),
#   (3, '#242', 'Normal', 'Blissey')],
#  [(1, '#114', 'Grass', 'Tangela'), (2, '#465', 'Grass', 'Tangrowth')],
#  [(1, '#116', 'Water', 'Horsea'),
#   (2, '#117', 'Water', 'Seadra'),
#   (3, '#230', 'Water · Dragon', 'Kingdra')],
#  [(1, '#118', 'Water', 'Goldeen'), (2, '#119', 'Water', 'Seaking')],
#  [(1, '#120', 'Water', 'Staryu'), (2, '#121', 'Water · Psychic', 'Starmie')],
#  [(1, '#439', 'Psychic · Fairy', 'Mime Jr.'),
#   (2, '#122', 'Psychic · Fairy', 'Mr. Mime')],
#  [(1, '#122', 'Galarian Mr. Mime', 'Mr. Mime'),
#   (2, '#866', 'Psychic · Ice', 'Mr. Rime')],
#  [(1, '#123', 'Bug · Flying', 'Scyther'),
#   (2, '#212', 'Bug · Steel', 'Scizor')],
#  [(1, '#238', 'Ice · Psychic', 'Smoochum'),
#   (2, '#124', 'Ice · Psychic', 'Jynx')],
#  [(1, '#239', 'Electric', 'Elekid'),
#   (2, '#125', 'Electric', 'Electabuzz'),
#   (3, '#466', 'Electric', 'Electivire')],
#  [(1, '#240', 'Fire', 'Magby'),
#   (2, '#126', 'Fire', 'Magmar'),
#   (3, '#467', 'Fire', 'Magmortar')],
#  [(1, '#129', 'Water', 'Magikarp'), (2, '#130', 'Water · Flying', 'Gyarados')],
#  [(1, '#133', 'Normal', 'Eevee'),
#   (2, '#134', 'Water', 'Vaporeon'),
#   (3, '#135', 'Electric', 'Jolteon'),
#   (4, '#136', 'Fire', 'Flareon')],
#  [(1, '#134', 'Water', 'Vaporeon')],
#  [(1, '#135', 'Electric', 'Jolteon')],
#  [(1, '#136', 'Fire', 'Flareon')],
#  [(1, '#133', 'Normal', 'Eevee'),
#   (2, '#196', 'Psychic', 'Espeon'),
#   (3, '#197', 'Dark', 'Umbreon')],
#  [(1, '#196', 'Psychic', 'Espeon')],
#  [(1, '#197', 'Dark', 'Umbreon')],
#  [(1, '#133', 'Normal', 'Eevee'),
#   (2, '#470', 'Grass', 'Leafeon'),
#   (3, '#471', 'Ice', 'Glaceon')],
#  [(1, '#470', 'Grass', 'Leafeon')],
#  [(1, '#471', 'Ice', 'Glaceon')],
#  [(1, '#133', 'Normal', 'Eevee'), (2, '#700', 'Fairy', 'Sylveon')],
#  [(1, '#137', 'Normal', 'Porygon'),
#   (2, '#233', 'Normal', 'Porygon2'),
#   (3, '#474', 'Normal', 'Porygon-Z')],
#  [(1, '#138', 'Rock · Water', 'Omanyte'),
#   (2, '#139', 'Rock · Water', 'Omastar')],
#  [(1, '#140', 'Rock · Water', 'Kabuto'),
#   (2, '#141', 'Rock · Water', 'Kabutops')],
#  [(1, '#446', 'Normal', 'Munchlax'), (2, '#143', 'Normal', 'Snorlax')],
#  [(1, '#147', 'Dragon', 'Dratini'),
#   (2, '#148', 'Dragon', 'Dragonair'),
#   (3, '#149', 'Dragon · Flying', 'Dragonite')],
#  [(1, '#152', 'Grass', 'Chikorita'),
#   (2, '#153', 'Grass', 'Bayleef'),
#   (3, '#154', 'Grass', 'Meganium')],
#  [(1, '#155', 'Fire', 'Cyndaquil'),
#   (2, '#156', 'Fire', 'Quilava'),
#   (3, '#157', 'Fire', 'Typhlosion')],
#  [(1, '#158', 'Water', 'Totodile'),
#   (2, '#159', 'Water', 'Croconaw'),
#   (3, '#160', 'Water', 'Feraligatr')],
#  [(1, '#161', 'Normal', 'Sentret'), (2, '#162', 'Normal', 'Furret')],
#  [(1, '#163', 'Normal · Flying', 'Hoothoot'),
#   (2, '#164', 'Normal · Flying', 'Noctowl')],
#  [(1, '#165', 'Bug · Flying', 'Ledyba'),
#   (2, '#166', 'Bug · Flying', 'Ledian')],
#  [(1, '#167', 'Bug · Poison', 'Spinarak'),
#   (2, '#168', 'Bug · Poison', 'Ariados')],
#  [(1, '#170', 'Water · Electric', 'Chinchou'),
#   (2, '#171', 'Water · Electric', 'Lanturn')],
#  [(1, '#175', 'Fairy', 'Togepi'),
#   (2, '#176', 'Fairy · Flying', 'Togetic'),
#   (3, '#468', 'Fairy · Flying', 'Togekiss')],
#  [(1, '#177', 'Psychic · Flying', 'Natu'),
#   (2, '#178', 'Psychic · Flying', 'Xatu')],
#  [(1, '#179', 'Electric', 'Mareep'),
#   (2, '#180', 'Electric', 'Flaaffy'),
#   (3, '#181', 'Electric', 'Ampharos')],
#  [(1, '#298', 'Normal · Fairy', 'Azurill'),
#   (2, '#183', 'Water · Fairy', 'Marill'),
#   (3, '#184', 'Water · Fairy', 'Azumarill')],
#  [(1, '#438', 'Rock', 'Bonsly'), (2, '#185', 'Rock', 'Sudowoodo')],
#  [(1, '#187', 'Grass · Flying', 'Hoppip'),
#   (2, '#188', 'Grass · Flying', 'Skiploom'),
#   (3, '#189', 'Grass · Flying', 'Jumpluff')],
#  [(1, '#190', 'Normal', 'Aipom'), (2, '#424', 'Normal', 'Ambipom')],
#  [(1, '#191', 'Grass', 'Sunkern'), (2, '#192', 'Grass', 'Sunflora')],
#  [(1, '#193', 'Bug · Flying', 'Yanma'),
#   (2, '#469', 'Bug · Flying', 'Yanmega')],
#  [(1, '#194', 'Water · Ground', 'Wooper'),
#   (2, '#195', 'Water · Ground', 'Quagsire')],
#  [(1, '#198', 'Dark · Flying', 'Murkrow'),
#   (2, '#430', 'Dark · Flying', 'Honchkrow')],
#  [(1, '#200', 'Ghost', 'Misdreavus'), (2, '#429', 'Ghost', 'Mismagius')],
#  [(1, '#360', 'Psychic', 'Wynaut'), (2, '#202', 'Psychic', 'Wobbuffet')],
#  [(1, '#204', 'Bug', 'Pineco'), (2, '#205', 'Bug · Steel', 'Forretress')],
#  [(1, '#207', 'Ground · Flying', 'Gligar'),
#   (2, '#472', 'Ground · Flying', 'Gliscor')],
#  [(1, '#209', 'Fairy', 'Snubbull'), (2, '#210', 'Fairy', 'Granbull')],
#  [(1, '#215', 'Dark · Ice', 'Sneasel'), (2, '#461', 'Dark · Ice', 'Weavile')],
#  [(1, '#216', 'Normal', 'Teddiursa'), (2, '#217', 'Normal', 'Ursaring')],
#  [(1, '#218', 'Fire', 'Slugma'), (2, '#219', 'Fire · Rock', 'Magcargo')],
#  [(1, '#220', 'Ice · Ground', 'Swinub'),
#   (2, '#221', 'Ice · Ground', 'Piloswine'),
#   (3, '#473', 'Ice · Ground', 'Mamoswine')],
#  [(1, '#223', 'Water', 'Remoraid'), (2, '#224', 'Water', 'Octillery')],
#  [(1, '#458', 'Water · Flying', 'Mantyke'),
#   (2, '#226', 'Water · Flying', 'Mantine')],
#  [(1, '#228', 'Dark · Fire', 'Houndour'),
#   (2, '#229', 'Dark · Fire', 'Houndoom')],
#  [(1, '#231', 'Ground', 'Phanpy'), (2, '#232', 'Ground', 'Donphan')],
#  [(1, '#246', 'Rock · Ground', 'Larvitar'),
#   (2, '#247', 'Rock · Ground', 'Pupitar'),
#   (3, '#248', 'Rock · Dark', 'Tyranitar')],
#  [(1, '#252', 'Grass', 'Treecko'),
#   (2, '#253', 'Grass', 'Grovyle'),
#   (3, '#254', 'Grass', 'Sceptile')],
#  [(1, '#255', 'Fire', 'Torchic'),
#   (2, '#256', 'Fire · Fighting', 'Combusken'),
#   (3, '#257', 'Fire · Fighting', 'Blaziken')],
#  [(1, '#258', 'Water', 'Mudkip'),
#   (2, '#259', 'Water · Ground', 'Marshtomp'),
#   (3, '#260', 'Water · Ground', 'Swampert')],
#  [(1, '#261', 'Dark', 'Poochyena'), (2, '#262', 'Dark', 'Mightyena')],
#  [(1, '#263', 'Normal', 'Zigzagoon'), (2, '#264', 'Normal', 'Linoone')],
#  [(1, '#263', 'Galarian Zigzagoon', 'Zigzagoon'),
#   (2, '#264', 'Galarian Linoone', 'Linoone'),
#   (3, '#862', 'Dark · Normal', 'Obstagoon')],
#  [(1, '#265', 'Bug', 'Wurmple'),
#   (2, '#266', 'Bug', 'Silcoon'),
#   (3, '#267', 'Bug · Flying', 'Beautifly'),
#   (4, '#268', 'Bug', 'Cascoon'),
#   (5, '#269', 'Bug · Poison', 'Dustox')],
#  [(1, '#266', 'Bug', 'Silcoon'), (2, '#267', 'Bug · Flying', 'Beautifly')],
#  [(1, '#268', 'Bug', 'Cascoon'), (2, '#269', 'Bug · Poison', 'Dustox')],
#  [(1, '#270', 'Water · Grass', 'Lotad'),
#   (2, '#271', 'Water · Grass', 'Lombre'),
#   (3, '#272', 'Water · Grass', 'Ludicolo')],
#  [(1, '#273', 'Grass', 'Seedot'),
#   (2, '#274', 'Grass · Dark', 'Nuzleaf'),
#   (3, '#275', 'Grass · Dark', 'Shiftry')],
#  [(1, '#276', 'Normal · Flying', 'Taillow'),
#   (2, '#277', 'Normal · Flying', 'Swellow')],
#  [(1, '#278', 'Water · Flying', 'Wingull'),
#   (2, '#279', 'Water · Flying', 'Pelipper')],
#  [(1, '#280', 'Psychic · Fairy', 'Ralts'),
#   (2, '#281', 'Psychic · Fairy', 'Kirlia'),
#   (3, '#282', 'Psychic · Fairy', 'Gardevoir'),
#   (4, '#475', 'Psychic · Fighting', 'Gallade')],
#  [(1, '#282', 'Psychic · Fairy', 'Gardevoir')],
#  [(1, '#475', 'Psychic · Fighting', 'Gallade')],
#  [(1, '#283', 'Bug · Water', 'Surskit'),
#   (2, '#284', 'Bug · Flying', 'Masquerain')],
#  [(1, '#285', 'Grass', 'Shroomish'),
#   (2, '#286', 'Grass · Fighting', 'Breloom')],
#  [(1, '#287', 'Normal', 'Slakoth'),
#   (2, '#288', 'Normal', 'Vigoroth'),
#   (3, '#289', 'Normal', 'Slaking')],
#  [(1, '#290', 'Bug · Ground', 'Nincada'),
#   (2, '#291', 'Bug · Flying', 'Ninjask'),
#   (3, '#291', 'Bug · Flying', 'Ninjask'),
#   (4, '#292', 'Bug · Ghost', 'Shedinja')],
#  [(1, '#291', 'Bug · Flying', 'Ninjask')],
#  [(1, '#291', 'Bug · Flying', 'Ninjask'),
#   (2, '#292', 'Bug · Ghost', 'Shedinja')],
#  [(1, '#293', 'Normal', 'Whismur'),
#   (2, '#294', 'Normal', 'Loudred'),
#   (3, '#295', 'Normal', 'Exploud')],
#  [(1, '#296', 'Fighting', 'Makuhita'), (2, '#297', 'Fighting', 'Hariyama')],
#  [(1, '#299', 'Rock', 'Nosepass'), (2, '#476', 'Rock · Steel', 'Probopass')],
#  [(1, '#300', 'Normal', 'Skitty'), (2, '#301', 'Normal', 'Delcatty')],
#  [(1, '#304', 'Steel · Rock', 'Aron'),
#   (2, '#305', 'Steel · Rock', 'Lairon'),
#   (3, '#306', 'Steel · Rock', 'Aggron')],
#  [(1, '#307', 'Fighting · Psychic', 'Meditite'),
#   (2, '#308', 'Fighting · Psychic', 'Medicham')],
#  [(1, '#309', 'Electric', 'Electrike'), (2, '#310', 'Electric', 'Manectric')],
#  [(1, '#406', 'Grass · Poison', 'Budew'),
#   (2, '#315', 'Grass · Poison', 'Roselia'),
#   (3, '#407', 'Grass · Poison', 'Roserade')],
#  [(1, '#316', 'Poison', 'Gulpin'), (2, '#317', 'Poison', 'Swalot')],
#  [(1, '#318', 'Water · Dark', 'Carvanha'),
#   (2, '#319', 'Water · Dark', 'Sharpedo')],
#  [(1, '#320', 'Water', 'Wailmer'), (2, '#321', 'Water', 'Wailord')],
#  [(1, '#322', 'Fire · Ground', 'Numel'),
#   (2, '#323', 'Fire · Ground', 'Camerupt')],
#  [(1, '#325', 'Psychic', 'Spoink'), (2, '#326', 'Psychic', 'Grumpig')],
#  [(1, '#328', 'Ground', 'Trapinch'),
#   (2, '#329', 'Ground · Dragon', 'Vibrava'),
#   (3, '#330', 'Ground · Dragon', 'Flygon')],
#  [(1, '#331', 'Grass', 'Cacnea'), (2, '#332', 'Grass · Dark', 'Cacturne')],
#  [(1, '#333', 'Normal · Flying', 'Swablu'),
#   (2, '#334', 'Dragon · Flying', 'Altaria')],
#  [(1, '#339', 'Water · Ground', 'Barboach'),
#   (2, '#340', 'Water · Ground', 'Whiscash')],
#  [(1, '#341', 'Water', 'Corphish'), (2, '#342', 'Water · Dark', 'Crawdaunt')],
#  [(1, '#343', 'Ground · Psychic', 'Baltoy'),
#   (2, '#344', 'Ground · Psychic', 'Claydol')],
#  [(1, '#345', 'Rock · Grass', 'Lileep'),
#   (2, '#346', 'Rock · Grass', 'Cradily')],
#  [(1, '#347', 'Rock · Bug', 'Anorith'), (2, '#348', 'Rock · Bug', 'Armaldo')],
#  [(1, '#349', 'Water', 'Feebas'), (2, '#350', 'Water', 'Milotic')],
#  [(1, '#353', 'Ghost', 'Shuppet'), (2, '#354', 'Ghost', 'Banette')],
#  [(1, '#355', 'Ghost', 'Duskull'),
#   (2, '#356', 'Ghost', 'Dusclops'),
#   (3, '#477', 'Ghost', 'Dusknoir')],
#  [(1, '#433', 'Psychic', 'Chingling'), (2, '#358', 'Psychic', 'Chimecho')],
#  [(1, '#361', 'Ice', 'Snorunt'),
#   (2, '#362', 'Ice', 'Glalie'),
#   (3, '#478', 'Ice · Ghost', 'Froslass')],
#  [(1, '#362', 'Ice', 'Glalie')],
#  [(1, '#478', 'Ice · Ghost', 'Froslass')],
#  [(1, '#363', 'Ice · Water', 'Spheal'),
#   (2, '#364', 'Ice · Water', 'Sealeo'),
#   (3, '#365', 'Ice · Water', 'Walrein')],
#  [(1, '#366', 'Water', 'Clamperl'),
#   (2, '#367', 'Water', 'Huntail'),
#   (3, '#368', 'Water', 'Gorebyss')],
#  [(1, '#367', 'Water', 'Huntail')],
#  [(1, '#368', 'Water', 'Gorebyss')],
#  [(1, '#371', 'Dragon', 'Bagon'),
#   (2, '#372', 'Dragon', 'Shelgon'),
#   (3, '#373', 'Dragon · Flying', 'Salamence')],
#  [(1, '#374', 'Steel · Psychic', 'Beldum'),
#   (2, '#375', 'Steel · Psychic', 'Metang'),
#   (3, '#376', 'Steel · Psychic', 'Metagross')],
#  [(1, '#387', 'Grass', 'Turtwig'),
#   (2, '#388', 'Grass', 'Grotle'),
#   (3, '#389', 'Grass · Ground', 'Torterra')],
#  [(1, '#390', 'Fire', 'Chimchar'),
#   (2, '#391', 'Fire · Fighting', 'Monferno'),
#   (3, '#392', 'Fire · Fighting', 'Infernape')],
#  [(1, '#393', 'Water', 'Piplup'),
#   (2, '#394', 'Water', 'Prinplup'),
#   (3, '#395', 'Water · Steel', 'Empoleon')],
#  [(1, '#396', 'Normal · Flying', 'Starly'),
#   (2, '#397', 'Normal · Flying', 'Staravia'),
#   (3, '#398', 'Normal · Flying', 'Staraptor')],
#  [(1, '#399', 'Normal', 'Bidoof'), (2, '#400', 'Normal · Water', 'Bibarel')],
#  [(1, '#401', 'Bug', 'Kricketot'), (2, '#402', 'Bug', 'Kricketune')],
#  [(1, '#403', 'Electric', 'Shinx'),
#   (2, '#404', 'Electric', 'Luxio'),
#   (3, '#405', 'Electric', 'Luxray')],
#  [(1, '#408', 'Rock', 'Cranidos'), (2, '#409', 'Rock', 'Rampardos')],
#  [(1, '#410', 'Rock · Steel', 'Shieldon'),
#   (2, '#411', 'Rock · Steel', 'Bastiodon')],
#  [(1, '#412', 'Bug', 'Burmy'), (2, '#414', 'Bug · Flying', 'Mothim')],
#  [(1, '#412', 'Bug', 'Burmy'),
#   (2, '#413', 'Plant Cloak', 'Wormadam'),
#   (3, '#413', 'Sandy Cloak', 'Wormadam'),
#   (4, '#413', 'Trash Cloak', 'Wormadam')],
#  [(1, '#413', 'Plant Cloak', 'Wormadam')],
#  [(1, '#413', 'Sandy Cloak', 'Wormadam')],
#  [(1, '#413', 'Trash Cloak', 'Wormadam')],
#  [(1, '#415', 'Bug · Flying', 'Combee'),
#   (2, '#416', 'Bug · Flying', 'Vespiquen')],
#  [(1, '#418', 'Water', 'Buizel'), (2, '#419', 'Water', 'Floatzel')],
#  [(1, '#420', 'Grass', 'Cherubi'), (2, '#421', 'Grass', 'Cherrim')],
#  [(1, '#422', 'Water', 'Shellos'), (2, '#423', 'Water · Ground', 'Gastrodon')],
#  [(1, '#425', 'Ghost · Flying', 'Drifloon'),
#   (2, '#426', 'Ghost · Flying', 'Drifblim')],
#  [(1, '#427', 'Normal', 'Buneary'), (2, '#428', 'Normal', 'Lopunny')],
#  [(1, '#431', 'Normal', 'Glameow'), (2, '#432', 'Normal', 'Purugly')],
#  [(1, '#434', 'Poison · Dark', 'Stunky'),
#   (2, '#435', 'Poison · Dark', 'Skuntank')],
#  [(1, '#436', 'Steel · Psychic', 'Bronzor'),
#   (2, '#437', 'Steel · Psychic', 'Bronzong')],
#  [(1, '#443', 'Dragon · Ground', 'Gible'),
#   (2, '#444', 'Dragon · Ground', 'Gabite'),
#   (3, '#445', 'Dragon · Ground', 'Garchomp')],
#  [(1, '#447', 'Fighting', 'Riolu'),
#   (2, '#448', 'Fighting · Steel', 'Lucario')],
#  [(1, '#449', 'Ground', 'Hippopotas'), (2, '#450', 'Ground', 'Hippowdon')],
#  [(1, '#451', 'Poison · Bug', 'Skorupi'),
#   (2, '#452', 'Poison · Dark', 'Drapion')],
#  [(1, '#453', 'Poison · Fighting', 'Croagunk'),
#   (2, '#454', 'Poison · Fighting', 'Toxicroak')],
#  [(1, '#456', 'Water', 'Finneon'), (2, '#457', 'Water', 'Lumineon')],
#  [(1, '#459', 'Grass · Ice', 'Snover'),
#   (2, '#460', 'Grass · Ice', 'Abomasnow')],
#  [(1, '#495', 'Grass', 'Snivy'),
#   (2, '#496', 'Grass', 'Servine'),
#   (3, '#497', 'Grass', 'Serperior')],
#  [(1, '#498', 'Fire', 'Tepig'),
#   (2, '#499', 'Fire · Fighting', 'Pignite'),
#   (3, '#500', 'Fire · Fighting', 'Emboar')],
#  [(1, '#501', 'Water', 'Oshawott'),
#   (2, '#502', 'Water', 'Dewott'),
#   (3, '#503', 'Water', 'Samurott')],
#  [(1, '#504', 'Normal', 'Patrat'), (2, '#505', 'Normal', 'Watchog')],
#  [(1, '#506', 'Normal', 'Lillipup'),
#   (2, '#507', 'Normal', 'Herdier'),
#   (3, '#508', 'Normal', 'Stoutland')],
#  [(1, '#509', 'Dark', 'Purrloin'), (2, '#510', 'Dark', 'Liepard')],
#  [(1, '#511', 'Grass', 'Pansage'), (2, '#512', 'Grass', 'Simisage')],
#  [(1, '#513', 'Fire', 'Pansear'), (2, '#514', 'Fire', 'Simisear')],
#  [(1, '#515', 'Water', 'Panpour'), (2, '#516', 'Water', 'Simipour')],
#  [(1, '#517', 'Psychic', 'Munna'), (2, '#518', 'Psychic', 'Musharna')],
#  [(1, '#519', 'Normal · Flying', 'Pidove'),
#   (2, '#520', 'Normal · Flying', 'Tranquill'),
#   (3, '#521', 'Normal · Flying', 'Unfezant')],
#  [(1, '#522', 'Electric', 'Blitzle'), (2, '#523', 'Electric', 'Zebstrika')],
#  [(1, '#524', 'Rock', 'Roggenrola'),
#   (2, '#525', 'Rock', 'Boldore'),
#   (3, '#526', 'Rock', 'Gigalith')],
#  [(1, '#527', 'Psychic · Flying', 'Woobat'),
#   (2, '#528', 'Psychic · Flying', 'Swoobat')],
#  [(1, '#529', 'Ground', 'Drilbur'),
#   (2, '#530', 'Ground · Steel', 'Excadrill')],
#  [(1, '#532', 'Fighting', 'Timburr'),
#   (2, '#533', 'Fighting', 'Gurdurr'),
#   (3, '#534', 'Fighting', 'Conkeldurr')],
#  [(1, '#535', 'Water', 'Tympole'),
#   (2, '#536', 'Water · Ground', 'Palpitoad'),
#   (3, '#537', 'Water · Ground', 'Seismitoad')],
#  [(1, '#540', 'Bug · Grass', 'Sewaddle'),
#   (2, '#541', 'Bug · Grass', 'Swadloon'),
#   (3, '#542', 'Bug · Grass', 'Leavanny')],
#  [(1, '#543', 'Bug · Poison', 'Venipede'),
#   (2, '#544', 'Bug · Poison', 'Whirlipede'),
#   (3, '#545', 'Bug · Poison', 'Scolipede')],
#  [(1, '#546', 'Grass · Fairy', 'Cottonee'),
#   (2, '#547', 'Grass · Fairy', 'Whimsicott')],
#  [(1, '#548', 'Grass', 'Petilil'), (2, '#549', 'Grass', 'Lilligant')],
#  [(1, '#551', 'Ground · Dark', 'Sandile'),
#   (2, '#552', 'Ground · Dark', 'Krokorok'),
#   (3, '#553', 'Ground · Dark', 'Krookodile')],
#  [(1, '#554', 'Fire', 'Darumaka'), (2, '#555', 'Standard Mode', 'Darmanitan')],
#  [(1, '#554', 'Galarian Darumaka', 'Darumaka'),
#   (2, '#555', 'Galarian Standard Mode', 'Darmanitan')],
#  [(1, '#557', 'Bug · Rock', 'Dwebble'), (2, '#558', 'Bug · Rock', 'Crustle')],
#  [(1, '#559', 'Dark · Fighting', 'Scraggy'),
#   (2, '#560', 'Dark · Fighting', 'Scrafty')],
#  [(1, '#562', 'Ghost', 'Yamask'), (2, '#563', 'Ghost', 'Cofagrigus')],
#  [(1, '#562', 'Galarian Yamask', 'Yamask'),
#   (2, '#867', 'Ground · Ghost', 'Runerigus')],
#  [(1, '#564', 'Water · Rock', 'Tirtouga'),
#   (2, '#565', 'Water · Rock', 'Carracosta')],
#  [(1, '#566', 'Rock · Flying', 'Archen'),
#   (2, '#567', 'Rock · Flying', 'Archeops')],
#  [(1, '#568', 'Poison', 'Trubbish'), (2, '#569', 'Poison', 'Garbodor')],
#  [(1, '#570', 'Dark', 'Zorua'), (2, '#571', 'Dark', 'Zoroark')],
#  [(1, '#572', 'Normal', 'Minccino'), (2, '#573', 'Normal', 'Cinccino')],
#  [(1, '#574', 'Psychic', 'Gothita'),
#   (2, '#575', 'Psychic', 'Gothorita'),
#   (3, '#576', 'Psychic', 'Gothitelle')],
#  [(1, '#577', 'Psychic', 'Solosis'),
#   (2, '#578', 'Psychic', 'Duosion'),
#   (3, '#579', 'Psychic', 'Reuniclus')],
#  [(1, '#580', 'Water · Flying', 'Ducklett'),
#   (2, '#581', 'Water · Flying', 'Swanna')],
#  [(1, '#582', 'Ice', 'Vanillite'),
#   (2, '#583', 'Ice', 'Vanillish'),
#   (3, '#584', 'Ice', 'Vanilluxe')],
#  [(1, '#585', 'Normal · Grass', 'Deerling'),
#   (2, '#586', 'Normal · Grass', 'Sawsbuck')],
#  [(1, '#588', 'Bug', 'Karrablast'), (2, '#589', 'Bug · Steel', 'Escavalier')],
#  [(1, '#590', 'Grass · Poison', 'Foongus'),
#   (2, '#591', 'Grass · Poison', 'Amoonguss')],
#  [(1, '#592', 'Water · Ghost', 'Frillish'),
#   (2, '#593', 'Water · Ghost', 'Jellicent')],
#  [(1, '#595', 'Bug · Electric', 'Joltik'),
#   (2, '#596', 'Bug · Electric', 'Galvantula')],
#  [(1, '#597', 'Grass · Steel', 'Ferroseed'),
#   (2, '#598', 'Grass · Steel', 'Ferrothorn')],
#  [(1, '#599', 'Steel', 'Klink'),
#   (2, '#600', 'Steel', 'Klang'),
#   (3, '#601', 'Steel', 'Klinklang')],
#  [(1, '#602', 'Electric', 'Tynamo'),
#   (2, '#603', 'Electric', 'Eelektrik'),
#   (3, '#604', 'Electric', 'Eelektross')],
#  [(1, '#605', 'Psychic', 'Elgyem'), (2, '#606', 'Psychic', 'Beheeyem')],
#  [(1, '#607', 'Ghost · Fire', 'Litwick'),
#   (2, '#608', 'Ghost · Fire', 'Lampent'),
#   (3, '#609', 'Ghost · Fire', 'Chandelure')],
#  [(1, '#610', 'Dragon', 'Axew'),
#   (2, '#611', 'Dragon', 'Fraxure'),
#   (3, '#612', 'Dragon', 'Haxorus')],
#  [(1, '#613', 'Ice', 'Cubchoo'), (2, '#614', 'Ice', 'Beartic')],
#  [(1, '#616', 'Bug', 'Shelmet'), (2, '#617', 'Bug', 'Accelgor')],
#  [(1, '#619', 'Fighting', 'Mienfoo'), (2, '#620', 'Fighting', 'Mienshao')],
#  [(1, '#622', 'Ground · Ghost', 'Golett'),
#   (2, '#623', 'Ground · Ghost', 'Golurk')],
#  [(1, '#624', 'Dark · Steel', 'Pawniard'),
#   (2, '#625', 'Dark · Steel', 'Bisharp')],
#  [(1, '#627', 'Normal · Flying', 'Rufflet'),
#   (2, '#628', 'Normal · Flying', 'Braviary')],
#  [(1, '#629', 'Dark · Flying', 'Vullaby'),
#   (2, '#630', 'Dark · Flying', 'Mandibuzz')],
#  [(1, '#633', 'Dark · Dragon', 'Deino'),
#   (2, '#634', 'Dark · Dragon', 'Zweilous'),
#   (3, '#635', 'Dark · Dragon', 'Hydreigon')],
#  [(1, '#636', 'Bug · Fire', 'Larvesta'),
#   (2, '#637', 'Bug · Fire', 'Volcarona')],
#  [(1, '#650', 'Grass', 'Chespin'),
#   (2, '#651', 'Grass', 'Quilladin'),
#   (3, '#652', 'Grass · Fighting', 'Chesnaught')],
#  [(1, '#653', 'Fire', 'Fennekin'),
#   (2, '#654', 'Fire', 'Braixen'),
#   (3, '#655', 'Fire · Psychic', 'Delphox')],
#  [(1, '#656', 'Water', 'Froakie'),
#   (2, '#657', 'Water', 'Frogadier'),
#   (3, '#658', 'Water · Dark', 'Greninja')],
#  [(1, '#659', 'Normal', 'Bunnelby'),
#   (2, '#660', 'Normal · Ground', 'Diggersby')],
#  [(1, '#661', 'Normal · Flying', 'Fletchling'),
#   (2, '#662', 'Fire · Flying', 'Fletchinder'),
#   (3, '#663', 'Fire · Flying', 'Talonflame')],
#  [(1, '#664', 'Bug', 'Scatterbug'),
#   (2, '#665', 'Bug', 'Spewpa'),
#   (3, '#666', 'Bug · Flying', 'Vivillon')],
#  [(1, '#667', 'Fire · Normal', 'Litleo'),
#   (2, '#668', 'Fire · Normal', 'Pyroar')],
#  [(1, '#669', 'Fairy', 'Flabébé'),
#   (2, '#670', 'Fairy', 'Floette'),
#   (3, '#671', 'Fairy', 'Florges')],
#  [(1, '#672', 'Grass', 'Skiddo'), (2, '#673', 'Grass', 'Gogoat')],
#  [(1, '#674', 'Fighting', 'Pancham'),
#   (2, '#675', 'Fighting · Dark', 'Pangoro')],
#  [(1, '#677', 'Psychic', 'Espurr'), (2, '#678', 'Male', 'Meowstic')],
#  [(1, '#679', 'Steel · Ghost', 'Honedge'),
#   (2, '#680', 'Steel · Ghost', 'Doublade'),
#   (3, '#681', 'Shield Forme', 'Aegislash')],
#  [(1, '#682', 'Fairy', 'Spritzee'), (2, '#683', 'Fairy', 'Aromatisse')],
#  [(1, '#684', 'Fairy', 'Swirlix'), (2, '#685', 'Fairy', 'Slurpuff')],
#  [(1, '#686', 'Dark · Psychic', 'Inkay'),
#   (2, '#687', 'Dark · Psychic', 'Malamar')],
#  [(1, '#688', 'Rock · Water', 'Binacle'),
#   (2, '#689', 'Rock · Water', 'Barbaracle')],
#  [(1, '#690', 'Poison · Water', 'Skrelp'),
#   (2, '#691', 'Poison · Dragon', 'Dragalge')],
#  [(1, '#692', 'Water', 'Clauncher'), (2, '#693', 'Water', 'Clawitzer')],
#  [(1, '#694', 'Electric · Normal', 'Helioptile'),
#   (2, '#695', 'Electric · Normal', 'Heliolisk')],
#  [(1, '#696', 'Rock · Dragon', 'Tyrunt'),
#   (2, '#697', 'Rock · Dragon', 'Tyrantrum')],
#  [(1, '#698', 'Rock · Ice', 'Amaura'), (2, '#699', 'Rock · Ice', 'Aurorus')],
#  [(1, '#704', 'Dragon', 'Goomy'),
#   (2, '#705', 'Dragon', 'Sliggoo'),
#   (3, '#706', 'Dragon', 'Goodra')],
#  [(1, '#708', 'Ghost · Grass', 'Phantump'),
#   (2, '#709', 'Ghost · Grass', 'Trevenant')],
#  [(1, '#710', 'Average Size', 'Pumpkaboo'),
#   (2, '#711', 'Average Size', 'Gourgeist')],
#  [(1, '#712', 'Ice', 'Bergmite'), (2, '#713', 'Ice', 'Avalugg')],
#  [(1, '#714', 'Flying · Dragon', 'Noibat'),
#   (2, '#715', 'Flying · Dragon', 'Noivern')],
#  [(1, '#722', 'Grass · Flying', 'Rowlet'),
#   (2, '#723', 'Grass · Flying', 'Dartrix'),
#   (3, '#724', 'Grass · Ghost', 'Decidueye')],
#  [(1, '#725', 'Fire', 'Litten'),
#   (2, '#726', 'Fire', 'Torracat'),
#   (3, '#727', 'Fire · Dark', 'Incineroar')],
#  [(1, '#728', 'Water', 'Popplio'),
#   (2, '#729', 'Water', 'Brionne'),
#   (3, '#730', 'Water · Fairy', 'Primarina')],
#  [(1, '#731', 'Normal · Flying', 'Pikipek'),
#   (2, '#732', 'Normal · Flying', 'Trumbeak'),
#   (3, '#733', 'Normal · Flying', 'Toucannon')],
#  [(1, '#734', 'Normal', 'Yungoos'), (2, '#735', 'Normal', 'Gumshoos')],
#  [(1, '#736', 'Bug', 'Grubbin'),
#   (2, '#737', 'Bug · Electric', 'Charjabug'),
#   (3, '#738', 'Bug · Electric', 'Vikavolt')],
#  [(1, '#739', 'Fighting', 'Crabrawler'),
#   (2, '#740', 'Fighting · Ice', 'Crabominable')],
#  [(1, '#742', 'Bug · Fairy', 'Cutiefly'),
#   (2, '#743', 'Bug · Fairy', 'Ribombee')],
#  [(1, '#744', 'Rock', 'Rockruff'),
#   (2, '#745', 'Midday Form', 'Lycanroc'),
#   (3, '#745', 'Midnight Form', 'Lycanroc')],
#  [(1, '#745', 'Midday Form', 'Lycanroc')],
#  [(1, '#745', 'Midnight Form', 'Lycanroc')],
#  [(1, '#744', 'Own Tempo Rockruff', 'Rockruff'),
#   (2, '#745', 'Dusk Form', 'Lycanroc')],
#  [(1, '#747', 'Poison · Water', 'Mareanie'),
#   (2, '#748', 'Poison · Water', 'Toxapex')],
#  [(1, '#749', 'Ground', 'Mudbray'), (2, '#750', 'Ground', 'Mudsdale')],
#  [(1, '#751', 'Water · Bug', 'Dewpider'),
#   (2, '#752', 'Water · Bug', 'Araquanid')],
#  [(1, '#753', 'Grass', 'Fomantis'), (2, '#754', 'Grass', 'Lurantis')],
#  [(1, '#755', 'Grass · Fairy', 'Morelull'),
#   (2, '#756', 'Grass · Fairy', 'Shiinotic')],
#  [(1, '#757', 'Poison · Fire', 'Salandit'),
#   (2, '#758', 'Poison · Fire', 'Salazzle')],
#  [(1, '#759', 'Normal · Fighting', 'Stufful'),
#   (2, '#760', 'Normal · Fighting', 'Bewear')],
#  [(1, '#761', 'Grass', 'Bounsweet'),
#   (2, '#762', 'Grass', 'Steenee'),
#   (3, '#763', 'Grass', 'Tsareena')],
#  [(1, '#767', 'Bug · Water', 'Wimpod'),
#   (2, '#768', 'Bug · Water', 'Golisopod')],
#  [(1, '#769', 'Ghost · Ground', 'Sandygast'),
#   (2, '#770', 'Ghost · Ground', 'Palossand')],
#  [(1, '#772', 'Normal', 'Type: Null'), (2, '#773', 'Normal', 'Silvally')],
#  [(1, '#782', 'Dragon', 'Jangmo-o'),
#   (2, '#783', 'Dragon · Fighting', 'Hakamo-o'),
#   (3, '#784', 'Dragon · Fighting', 'Kommo-o')],
#  [(1, '#789', 'Psychic', 'Cosmog'),
#   (2, '#790', 'Psychic', 'Cosmoem'),
#   (3, '#791', 'Psychic · Steel', 'Solgaleo'),
#   (4, '#792', 'Psychic · Ghost', 'Lunala')],
#  [(1, '#791', 'Psychic · Steel', 'Solgaleo')],
#  [(1, '#792', 'Psychic · Ghost', 'Lunala')],
#  [(1, '#803', 'Poison', 'Poipole'),
#   (2, '#804', 'Poison · Dragon', 'Naganadel')],
#  [(1, '#808', 'Steel', 'Meltan'), (2, '#809', 'Steel', 'Melmetal')],
#  [(1, '#810', 'Grass', 'Grookey'),
#   (2, '#811', 'Grass', 'Thwackey'),
#   (3, '#812', 'Grass', 'Rillaboom')],
#  [(1, '#813', 'Fire', 'Scorbunny'),
#   (2, '#814', 'Fire', 'Raboot'),
#   (3, '#815', 'Fire', 'Cinderace')],
#  [(1, '#816', 'Water', 'Sobble'),
#   (2, '#817', 'Water', 'Drizzile'),
#   (3, '#818', 'Water', 'Inteleon')],
#  [(1, '#824', 'Bug', 'Blipbug'),
#   (2, '#825', 'Bug · Psychic', 'Dottler'),
#   (3, '#826', 'Bug · Psychic', 'Orbeetle')],
#  [(1, '#821', 'Flying', 'Rookidee'),
#   (2, '#822', 'Flying', 'Corvisquire'),
#   (3, '#823', 'Flying · Steel', 'Corviknight')],
#  [(1, '#819', 'Normal', 'Skwovet'), (2, '#820', 'Normal', 'Greedent')],
#  [(1, '#827', 'Dark', 'Nickit'), (2, '#828', 'Dark', 'Thievul')],
#  [(1, '#831', 'Normal', 'Wooloo'), (2, '#832', 'Normal', 'Dubwool')],
#  [(1, '#833', 'Water', 'Chewtle'), (2, '#834', 'Water · Rock', 'Drednaw')],
#  [(1, '#835', 'Electric', 'Yamper'), (2, '#836', 'Electric', 'Boltund')],
#  [(1, '#829', 'Grass', 'Gossifleur'), (2, '#830', 'Grass', 'Eldegoss')],
#  [(1, '#850', 'Fire · Bug', 'Sizzlipede'),
#   (2, '#851', 'Fire · Bug', 'Centiskorch')],
#  [(1, '#837', 'Rock', 'Rolycoly'),
#   (2, '#838', 'Rock · Fire', 'Carkol'),
#   (3, '#839', 'Rock · Fire', 'Coalossal')],
#  [(1, '#846', 'Water', 'Arrokuda'), (2, '#847', 'Water', 'Barraskewda')],
#  [(1, '#868', 'Fairy', 'Milcery'), (2, '#869', 'Fairy', 'Alcremie')],
#  [(1, '#840', 'Grass · Dragon', 'Applin'),
#   (2, '#841', 'Grass · Dragon', 'Flapple')],
#  [(1, '#840', 'Grass · Dragon', 'Applin'),
#   (2, '#842', 'Grass · Dragon', 'Appletun')],
#  [(1, '#083', "Galarian Farfetch'd", "Farfetch'd"),
#   (2, '#865', 'Fighting', "Sirfetch'd")],
#  [(1, '#222', 'Galarian Corsola', 'Corsola'), (2, '#864', 'Ghost', 'Cursola')],
#  [(1, '#859', 'Dark · Fairy', 'Impidimp'),
#   (2, '#860', 'Dark · Fairy', 'Morgrem'),
#   (3, '#861', 'Dark · Fairy', 'Grimmsnarl')],
#  [(1, '#856', 'Psychic', 'Hatenna'),
#   (2, '#857', 'Psychic', 'Hattrem'),
#   (3, '#858', 'Psychic · Fairy', 'Hatterene')],
#  [(1, '#878', 'Steel', 'Cufant'), (2, '#879', 'Steel', 'Copperajah')],
#  [(1, '#848', 'Electric · Poison', 'Toxel'),
#   (2, '#849', 'Low Key Form', 'Toxtricity')],
#  [(1, '#848', 'Electric · Poison', 'Toxel'),
#   (2, '#849', 'Amped Form', 'Toxtricity')],
#  [(1, '#843', 'Ground', 'Silicobra'), (2, '#844', 'Ground', 'Sandaconda')],
#  [(1, '#854', 'Ghost', 'Sinistea'), (2, '#855', 'Ghost', 'Polteageist')],
#  [(1, '#872', 'Ice · Bug', 'Snom'), (2, '#873', 'Ice · Bug', 'Frosmoth')],
#  [(1, '#852', 'Fighting', 'Clobbopus'), (2, '#853', 'Fighting', 'Grapploct')],
#  [(1, '#885', 'Dragon · Ghost', 'Dreepy'),
#   (2, '#886', 'Dragon · Ghost', 'Drakloak'),
#   (3, '#887', 'Dragon · Ghost', 'Dragapult')],
#  [(1, '#891', 'Fighting', 'Kubfu'),
#   (2, '#892', 'Single Strike Style', 'Urshifu'),
#   (3, '#892', 'Rapid Strike Style', 'Urshifu')],
#  [(1, '#892', 'Single Strike Style', 'Urshifu')],
#  [(1, '#892', 'Rapid Strike Style', 'Urshifu')]]

# %%
#And what better way to do all this than list comprehensions! 
step_1 = [[elem for elem in branch_list if 'Alol' not in elem[2]] for branch_list in raw] ## Remove all touples that contain 'Alol' in the small text (removing the second Raichu in our example)
step_2 = [[elem for elem in branch_list if (int(elem[1][1:]) > 251 and int(elem[1][1:])<495)] for branch_list in step_1] ## Remove all pokemon that are after Gen 2 (Number > 251) 
step_3 = [elem for elem in step_2 if len(elem) > 1] ##Remove entries that have a length of 1 or less (remove leftovers that are not actual branches in Gens 1 & 2)

# %%
has_evolution = [[elem[3] for elem in branch_list] for branch_list in step_3] ## Extract all pokemon that in the raw list
has_evolution = sum(has_evolution, []) ## 'Un-tupple' them -- This is not the optimal way to do this but I find it really really cool and for such a small list it doesn't matter

# %%
last_evolutions  = [x[-1] for x in step_3] ## Take the last entry into each element list
last_evolutions.extend([x[-2] for x in step_3 if x[-1][0] == 4]) # The ones that have 2 end evolutions like Politoed and Poliwrath

## This is the eevee and hitmontop section as they have 5 and 3 final evolutions respecitvely
eevee_and_hitmon = [x[1:] for x in step_3 if (x[0][3] == 'Tyrogue') or (x[0][3] ==  'Eevee')]
eevee_and_hitmon = sum(eevee_and_hitmon, [])
last_evolutions.extend(eevee_and_hitmon)

last_evo_df = pd.DataFrame([[int(x[1][1:]), x[3]] for x in last_evolutions], columns=['Number', 'Pokemon'] )
last_evo_df = last_evo_df.drop_duplicates() ## Remove duplicates because some hitmontop and eevee evolutions have been added more than once in the process

# %%
my_pokemon['Has_evol'] = my_pokemon.Name.isin(has_evolution)
my_pokemon['Last_evol'] = my_pokemon.Name.isin(last_evo_df.Pokemon)
my_evolved_pokemon = my_pokemon.loc[(my_pokemon.Last_evol == True) | (my_pokemon.Has_evol == False)].copy()

# %%
(f, axes) = attr_per_type(my_evolved_pokemon, 'Type 1', 'Legendary')
_ = f.suptitle('Attributes broken down by type for last evolution pokemon', va='center', y=0.92)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1296: UserWarning:
#
# 7.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1296: UserWarning:
#
# 7.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1296: UserWarning:
#
# 7.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 10))
mpl.rcParams["font.size"] = 12

ax1 = my_evolved_pokemon.groupby('Type 2').size().sort_values().plot(kind='barh', ax=ax1)
start, end = ax1.get_xlim()
ax1.xaxis.set_ticks(np.arange(start, end, 5))
ax1.axes.get_yaxis().get_label().set_visible(False)
_ = ax1.set_title('Type 2 frequency')

pivot_dat = my_evolved_pokemon.pivot_table(index='Type 1', columns='Type 2', aggfunc = 'size')
pivot_dat = pivot_dat[pivot_dat.sum().sort_values(ascending = False).index] #Reordering
ax2 = sns.heatmap(pivot_dat, annot=True, square=True, cmap=sns.color_palette("Blues"), cbar=False, linewidths=0.3, ax=ax2)
_ = ax2.set_title('Type 1 - Type 2 pairs')
fig.tight_layout()

# %%
my_evolved_pokemon['New type'] = my_evolved_pokemon['Type 1']
my_evolved_pokemon['Dual type'] = ~pd.isnull(my_pokemon['Type 2'])
dual_evolved_pokemon = my_evolved_pokemon.append(my_evolved_pokemon[my_evolved_pokemon['Dual type']==True], ignore_index=True)

#Change the second instance of the pokemon to have the second type
dual_evolved_pokemon.loc[dual_evolved_pokemon.duplicated(), 'New type'] = dual_evolved_pokemon.loc[dual_evolved_pokemon.duplicated(), 'Type 2']

# %%
(f, axes) = attr_per_type(dual_evolved_pokemon, 'New type', 'Dual type')
_ = f.suptitle("Attributes broken down by type (Yellow indicates dual type)", va='center', y=0.92)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1296: UserWarning:
#
# 7.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1296: UserWarning:
#
# 6.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1296: UserWarning:
#
# 7.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.

# %%
def create_radar_chart(input_df, group_col, col_num):
    poke_stats = input_df.loc[:, 'HP':'Speed']
    norm_poke_stats = poke_stats / poke_stats.max() #Let's normalise the data 
    radar_dat = pd.concat([norm_poke_stats, input_df.loc[:, [group_col, 'Name']]], axis=1)
    radar_dat_short = radar_dat.groupby([group_col]).mean().loc[:,['HP', 'Defense', 'Sp. Def', 'Speed', 'Sp. Atk', 'Attack']]
    radar_dat_short.columns = ['HP', 'Def', 'Sp. Def', 'Speed', 'Sp. Atk', 'Atk']

    fig = make_subplots(rows=4, cols=col_num, vertical_spacing = 0.08, horizontal_spacing=0.04, specs=[[{"type": "polar"}]*col_num]*4,  subplot_titles=radar_dat_short.index.values)
    chart_counter = 0

    for type in radar_dat_short.index.values:

        fig.add_trace(go.Scatterpolar(
              r=radar_dat_short.loc[type].values,
              theta=list(radar_dat_short.loc[type].index),
              fill='toself',
              name=type),
              row=chart_counter // col_num + 1, col=chart_counter % col_num + 1
        )
        chart_counter += 1

    initial_elements = [elem*col_num+1 for elem in range(4)]    
    polar_initial_list = ['polar' + str(num) for num in initial_elements]
    polar_rest_list = ['polar' + str(num) for num in list(set(range(1,18)) - set(initial_elements))]

    polar_initial = {pol: dict(
                radialaxis=dict(
                  visible=False,
                  range=[0, 1]
                ),

                angularaxis = dict(
                    #categoryorder = ['Defense', 'Attack', 'Sp. Def', 'Sp. Atk', 'Speed', 'HP']
                     categoryorder = 'array',
                    categoryarray = ['HP', 'Def', 'Sp. Def', 'Speed', 'Sp. Atk', 'Atk'],
                    rotation = 90
                )
                  ) for pol in polar_initial_list}

    polar_rest = {pol: dict(
                radialaxis=dict(
                  visible=False,
                  range=[0, 1]
                ),

                angularaxis = dict(
                    #categoryorder = ['Defense', 'Attack', 'Sp. Def', 'Sp. Atk', 'Speed', 'HP']
                     categoryorder = 'array',
                    categoryarray = ['HP', 'Def', 'Sp. Def', 'Speed', 'Sp. Atk', 'Atk'],
                    showticklabels=False,
                    rotation = 90
                )
                  ) for pol in polar_rest_list}

    polar_dict = {**polar_initial, **polar_rest}
    fig.update_layout(
              polar_dict,
              height = 800,
              width = 800,
              font=dict(size=8),
              showlegend=False,
              title={'text': "Average stats per pokemon type",
                     'font_size':15,
                     'y':0.95,
                     'x':0.5,
                     'xanchor': 'center',
                     'yanchor': 'top'}
              )
    
    fig_counter = 1
    for i in fig['layout']['annotations']:
        i['font'] = dict(size=12)
        if fig_counter in initial_elements:
            i['height'] = 35
        else:
            i['height'] = 15
        fig_counter += 1
    return(fig)
    #fig['layout'].xaxis1[{'automargin' : 'False'}]
    #fig.show()

# %%
f = create_radar_chart(my_evolved_pokemon, 'Type 1', 4)
f.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="5b67e895-cd6b-45c5-be98-8778085f9a7f" class="plotly-graph-div" style="height:800px; width:800px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5b67e895-cd6b-45c5-be98-8778085f9a7f")) {
#                     Plotly.newPlot(
#                         '5b67e895-cd6b-45c5-be98-8778085f9a7f',
#                         [{"fill": "toself", "name": "Bug", "r": [0.36344537815126055, 0.34142857142857136, 0.3557142857142857, 0.37063492063492065, 0.38968253968253974, 0.4055555555555556], "subplot": "polar", "theta": ["HP", "Def", "Sp. Def", "Speed", "Sp. Atk", "Atk"], "type": "scatterpolar"}, {"fill": "toself", "name": "Dark", "r": [0.4166666666666666, 0.3433333333333333, 0.3433333333333333, 0.47777777777777786, 0.4490740740740741, 0.5833333333333333], "subplot": "polar2", "theta": ["HP", "Def", "Sp. Def", "Speed", "Sp. Atk", "Atk"], "type": "scatterpolar"}, {"fill": "toself", "name": "Dragon", "r": [0.5323529411764706, 0.43750000000000006, 0.5, 0.5527777777777777, 0.601851851851852, 0.6064814814814815], "subplot": "polar3", "theta": ["HP", "Def", "Sp. Def", "Speed", "Sp. Atk", "Atk"], "type": "scatterpolar"}, {"fill": "toself", "name": "Electric", "r": [0.35067873303167413, 0.42038461538461547, 0.45230769230769236, 0.48547008547008547, 0.5341880341880341, 0.3837606837606837], "subplot": "polar4", "theta": ["HP", "Def", "Sp. Def", "Speed", "Sp. Atk", "Atk"], "type": "scatterpolar"}, {"fill": "toself", "name": "Fighting", "r": [0.5372549019607843, 0.3416666666666666, 0.3416666666666666, 0.40740740740740744, 0.39814814814814814, 0.5370370370370371], "subplot": "polar5", "theta": ["HP", "Def", "Sp. Def", "Speed", "Sp. Atk", "Atk"], "type": "scatterpolar"}, {"fill": "toself", "name": "Fire", "r": [0.4529411764705882, 0.4366666666666667, 0.40583333333333327, 0.37777777777777777, 0.6101851851851853, 0.5499999999999999], "subplot": "polar6", "theta": ["HP", "Def", "Sp. Def", "Speed", "Sp. Atk", "Atk"], "type": "scatterpolar"}, {"fill": "toself", "name": "Ghost", "r": [0.5621848739495798, 0.45142857142857146, 0.4892857142857143, 0.4047619047619047, 0.5198412698412699, 0.5293650793650794], "subplot": "polar7", "theta": ["HP", "Def", "Sp. Def", "Speed", "Sp. Atk", "Atk"], "type": "scatterpolar"}, {"fill": "toself", "name": "Grass", "r": [0.48778280542986424, 0.3980769230769231, 0.3853846153846154, 0.42307692307692313, 0.5303418803418803, 0.5264957264957264], "subplot": "polar8", "theta": ["HP", "Def", "Sp. Def", "Speed", "Sp. Atk", "Atk"], "type": "scatterpolar"}, {"fill": "toself", "name": "Ground", "r": [0.5361344537815126, 0.6128571428571428, 0.41571428571428565, 0.4261904761904762, 0.45079365079365086, 0.6722222222222223], "subplot": "polar9", "theta": ["HP", "Def", "Sp. Def", "Speed", "Sp. Atk", "Atk"], "type": "scatterpolar"}, {"fill": "toself", "name": "Ice", "r": [0.5117647058823529, 0.45, 0.5149999999999999, 0.4111111111111111, 0.5277777777777779, 0.4444444444444445], "subplot": "polar10", "theta": ["HP", "Def", "Sp. Def", "Speed", "Sp. Atk", "Atk"], "type": "scatterpolar"}, {"fill": "toself", "name": "Normal", "r": [0.5040920716112531, 0.3419565217391304, 0.37, 0.43768115942028984, 0.3806763285024154, 0.4683574879227053], "subplot": "polar11", "theta": ["HP", "Def", "Sp. Def", "Speed", "Sp. Atk", "Atk"], "type": "scatterpolar"}, {"fill": "toself", "name": "Poison", "r": [0.5047058823529411, 0.385, 0.344, 0.42666666666666664, 0.4333333333333333, 0.5133333333333334], "subplot": "polar12", "theta": ["HP", "Def", "Sp. Def", "Speed", "Sp. Atk", "Atk"], "type": "scatterpolar"}, {"fill": "toself", "name": "Psychic", "r": [0.39747899159663863, 0.39392857142857146, 0.46892857142857153, 0.528968253968254, 0.532936507936508, 0.4773809523809524], "subplot": "polar13", "theta": ["HP", "Def", "Sp. Def", "Speed", "Sp. Atk", "Atk"], "type": "scatterpolar"}, {"fill": "toself", "name": "Rock", "r": [0.4235294117647059, 0.5638888888888888, 0.4555555555555555, 0.2567901234567901, 0.3382716049382716, 0.49876543209876534], "subplot": "polar14", "theta": ["HP", "Def", "Sp. Def", "Speed", "Sp. Atk", "Atk"], "type": "scatterpolar"}, {"fill": "toself", "name": "Steel", "r": [0.4596638655462185, 0.6292857142857143, 0.47928571428571426, 0.3515873015873016, 0.4873015873015873, 0.5666666666666667], "subplot": "polar15", "theta": ["HP", "Def", "Sp. Def", ...
#                         {"annotations": [{"font": {"size": 12}, "height": 35, "showarrow": false, "text": "Bug", "x": 0.11, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 12}, "height": 15, "showarrow": false, "text": "Dark", "x": 0.37, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 12}, "height": 15, "showarrow": false, "text": "Dragon", "x": 0.63, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 12}, "height": 15, "showarrow": false, "text": "Electric", "x": 0.89, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 12}, "height": 35, "showarrow": false, "text": "Fighting", "x": 0.11, "xanchor": "center", "xref": "paper", "y": 0.73, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 12}, "height": 15, "showarrow": false, "text": "Fire", "x": 0.37, "xanchor": "center", "xref": "paper", "y": 0.73, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 12}, "height": 15, "showarrow": false, "text": "Ghost", "x": 0.63, "xanchor": "center", "xref": "paper", "y": 0.73, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 12}, "height": 15, "showarrow": false, "text": "Grass", "x": 0.89, "xanchor": "center", "xref": "paper", "y": 0.73, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 12}, "height": 35, "showarrow": false, "text": "Ground", "x": 0.11, "xanchor": "center", "xref": "paper", "y": 0.46, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 12}, "height": 15, "showarrow": false, "text": "Ice", "x": 0.37, "xanchor": "center", "xref": "paper", "y": 0.46, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 12}, "height": 15, "showarrow": false, "text": "Normal", "x": 0.63, "xanchor": "center", "xref": "paper", "y": 0.46, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 12}, "height": 15, "showarrow": false, "text": "Poison", "x": 0.89, "xanchor": "center", "xref": "paper", "y": 0.46, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 12}, "height": 35, "showarrow": false, "text": "Psychic", "x": 0.11, "xanchor": "center", "xref": "paper", "y": 0.19, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 12}, "height": 15, "showarrow": false, "text": "Rock", "x": 0.37, "xanchor": "center", "xref": "paper", "y": 0.19, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 12}, "height": 15, "showarrow": false, "text": "Steel", "x": 0.63, "xanchor": "center", "xref": "paper", "y": 0.19, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 12}, "height": 15, "showarrow": false, "text": "Water", "x": 0.89, "xanchor": "center"

# %%
f = create_radar_chart(dual_evolved_pokemon, 'New type', 5)
f.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1b12d839-3e23-416c-81d2-d61b7c4af06e" class="plotly-graph-div" style="height:800px; width:800px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1b12d839-3e23-416c-81d2-d61b7c4af06e")) {
#                     Plotly.newPlot(
#                         '1b12d839-3e23-416c-81d2-d61b7c4af06e',
#                         [{"fill": "toself", "name": "Bug", "r": [0.36862745098039224, 0.352, 0.35866666666666663, 0.36259259259259263, 0.3896296296296297, 0.4248148148148149], "subplot": "polar", "theta": ["HP", "Def", "Sp. Def", "Speed", "Sp. Atk", "Atk"], "type": "scatterpolar"}, {"fill": "toself", "name": "Dark", "r": [0.42579185520361984, 0.36230769230769233, 0.335, 0.4337606837606838, 0.46923076923076923, 0.5811965811965811], "subplot": "polar2", "theta": ["HP", "Def", "Sp. Def", "Speed", "Sp. Atk", "Atk"], "type": "scatterpolar"}, {"fill": "toself", "name": "Dragon", "r": [0.5951871657754011, 0.475, 0.509090909090909, 0.5388888888888889, 0.6313131313131314, 0.6136363636363638], "subplot": "polar3", "theta": ["HP", "Def", "Sp. Def", "Speed", "Sp. Atk", "Atk"], "type": "scatterpolar"}, {"fill": "toself", "name": "Electric", "r": [0.35067873303167413, 0.42038461538461547, 0.45230769230769236, 0.48547008547008547, 0.5341880341880341, 0.3837606837606837], "subplot": "polar4", "theta": ["HP", "Def", "Sp. Def", "Speed", "Sp. Atk", "Atk"], "type": "scatterpolar"}, {"fill": "toself", "name": "Fighting", "r": [0.47132352941176475, 0.34750000000000003, 0.3662500000000001, 0.44652777777777786, 0.4444444444444445, 0.6076388888888888], "subplot": "polar5", "theta": ["HP", "Def", "Sp. Def", "Speed", "Sp. Atk", "Atk"], "type": "scatterpolar"}, {"fill": "toself", "name": "Fire", "r": [0.44999999999999996, 0.494375, 0.4275, 0.40555555555555556, 0.6347222222222222, 0.5826388888888888], "subplot": "polar6", "theta": ["HP", "Def", "Sp. Def", "Speed", "Sp. Atk", "Atk"], "type": "scatterpolar"}, {"fill": "toself", "name": "Flying", "r": [0.46974789915966386, 0.3716666666666666, 0.3742857142857143, 0.4714285714285714, 0.4878306878306878, 0.4632275132275132], "subplot": "polar7", "theta": ["HP", "Def", "Sp. Def", "Speed", "Sp. Atk", "Atk"], "type": "scatterpolar"}, {"fill": "toself", "name": "Ghost", "r": [0.44919786096256686, 0.40863636363636363, 0.42136363636363633, 0.4045454545454545, 0.4671717171717171, 0.48585858585858593], "subplot": "polar8", "theta": ["HP", "Def", "Sp. Def", "Speed", "Sp. Atk", "Atk"], "type": "scatterpolar"}, {"fill": "toself", "name": "Grass", "r": [0.46851211072664356, 0.41000000000000003, 0.41794117647058826, 0.400326797385621, 0.5215686274509804, 0.4924836601307189], "subplot": "polar9", "theta": ["HP", "Def", "Sp. Def", "Speed", "Sp. Atk", "Atk"], "type": "scatterpolar"}, {"fill": "toself", "name": "Ground", "r": [0.5498039215686273, 0.5146666666666666, 0.40499999999999997, 0.3740740740740741, 0.44814814814814824, 0.6170370370370369], "subplot": "polar10", "theta": ["HP", "Def", "Sp. Def", "Speed", "Sp. Atk", "Atk"], "type": "scatterpolar"}, {"fill": "toself", "name": "Ice", "r": [0.47426470588235287, 0.43562500000000004, 0.49499999999999994, 0.44513888888888886, 0.49791666666666673, 0.4701388888888889], "subplot": "polar11", "theta": ["HP", "Def", "Sp. Def", "Speed", "Sp. Atk", "Atk"], "type": "scatterpolar"}, {"fill": "toself", "name": "Normal", "r": [0.5040920716112531, 0.3419565217391304, 0.37, 0.43768115942028984, 0.3806763285024154, 0.4683574879227053], "subplot": "polar12", "theta": ["HP", "Def", "Sp. Def", "Speed", "Sp. Atk", "Atk"], "type": "scatterpolar"}, {"fill": "toself", "name": "Poison", "r": [0.4613445378151261, 0.37142857142857144, 0.38499999999999995, 0.42777777777777776, 0.4484126984126983, 0.46190476190476193], "subplot": "polar13", "theta": ["HP", "Def", "Sp. Def", "Speed", "Sp. Atk", "Atk"], "type": "scatterpolar"}, {"fill": "toself", "name": "Psychic", "r": [0.4125319693094629, 0.4236956521739131, 0.47913043478260875, 0.4954106280193237, 0.5161835748792271, 0.477536231884058], "subplot": "polar14", "theta": ["HP", "Def", "Sp. Def", "Speed", "Sp. Atk", "Atk"], "type": "scatterpolar"}, {"fill": "toself", "name": "Rock", "r": [0.4573529411764706, 0.6062500000000001, 0.4166666666666667, 0.2597222222222222, 0.3277777777777778, 0.5314814814814814], "subplot": "polar15", "theta": ["HP", "Def", "Sp.  ...
#                         {"annotations": [{"font": {"size": 12}, "height": 35, "showarrow": false, "text": "Bug", "x": 0.08399999999999999, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 12}, "height": 15, "showarrow": false, "text": "Dark", "x": 0.292, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 12}, "height": 15, "showarrow": false, "text": "Dragon", "x": 0.5, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 12}, "height": 15, "showarrow": false, "text": "Electric", "x": 0.708, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 12}, "height": 15, "showarrow": false, "text": "Fighting", "x": 0.9159999999999999, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 12}, "height": 35, "showarrow": false, "text": "Fire", "x": 0.08399999999999999, "xanchor": "center", "xref": "paper", "y": 0.73, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 12}, "height": 15, "showarrow": false, "text": "Flying", "x": 0.292, "xanchor": "center", "xref": "paper", "y": 0.73, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 12}, "height": 15, "showarrow": false, "text": "Ghost", "x": 0.5, "xanchor": "center", "xref": "paper", "y": 0.73, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 12}, "height": 15, "showarrow": false, "text": "Grass", "x": 0.708, "xanchor": "center", "xref": "paper", "y": 0.73, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 12}, "height": 15, "showarrow": false, "text": "Ground", "x": 0.9159999999999999, "xanchor": "center", "xref": "paper", "y": 0.73, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 12}, "height": 35, "showarrow": false, "text": "Ice", "x": 0.08399999999999999, "xanchor": "center", "xref": "paper", "y": 0.46, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 12}, "height": 15, "showarrow": false, "text": "Normal", "x": 0.292, "xanchor": "center", "xref": "paper", "y": 0.46, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 12}, "height": 15, "showarrow": false, "text": "Poison", "x": 0.5, "xanchor": "center", "xref": "paper", "y": 0.46, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 12}, "height": 15, "showarrow": false, "text": "Psychic", "x": 0.708, "xanchor": "center", "

# %%
my_evolved_pokemon = my_pokemon.loc[(my_pokemon.Last_evol == True) | (my_pokemon.Has_evol == False)].copy()

# %% [markdown]
# # Modelos para saber si son o no legendarios

# %%
X = my_evolved_pokemon.drop(columns =['Name', 'Type 1', 'Type 2', 'Generation', 'Legendary', 'Has_evol', 'Last_evol'])
y = my_evolved_pokemon['Legendary']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier as DT
from sklearn.ensemble import RandomForestClassifier as RF

alg1 = LogisticRegression()
alg2 = SVC(kernel = 'rbf')
alg3 = RF()
alg4 = DT()

# %%
from sklearn.metrics import accuracy_score
alg1.fit(X_train, y_train) #Training the model
pd.DataFrame({"Accurancy on Train":[accuracy_score(y_train, alg1.predict(X_train))],
    "Accurancy on Test":[accuracy_score(y_test, alg1.predict(X_test))]})
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#    Accurancy on Train  Accurancy on Test
# 0            0.991597              0.975

# %%
alg2.fit(X_train, y_train) #Training the model
pd.DataFrame({"Accurancy on Train":[accuracy_score(y_train, alg2.predict(X_train))],
    "Accurancy on Test":[accuracy_score(y_test, alg2.predict(X_test))]})
# Out:
#    Accurancy on Train  Accurancy on Test
# 0             0.92437                1.0

# %%
alg3.fit(X_train, y_train) #Training the model
pd.DataFrame({"Accurancy on Train":[accuracy_score(y_train, alg3.predict(X_train))],
    "Accurancy on Test":[accuracy_score(y_test, alg3.predict(X_test))]})
# Out:
#    Accurancy on Train  Accurancy on Test
# 0            0.991597              0.925

# %%
alg4.fit(X_train, y_train) #Training the model
pd.DataFrame({"Accurancy on Train":[accuracy_score(y_train, alg4.predict(X_train))],
    "Accurancy on Test":[accuracy_score(y_test, alg4.predict(X_test))]})
# Out:
#    Accurancy on Train  Accurancy on Test
# 0            0.991597               0.95

# %%
test = np.array([[720.0,120.0,120.0,120.0,120.0,120.0,120.0]])
test2 = np.array([[680.0,106.0,110.0,90.0,154.0,90.0,130.0]]) #mewtwo
test3 = np.array([[318.0,45.0,49.0,49.0,65.0,65.0,45.0]])#bulbasaur

# %%
print(alg1.predict(test)[0])
print(alg1.predict(test2)[0])
print(alg1.predict(test3)[0])
# Out:
# True
# True
# False

# %%
print(alg2.predict(test)[0])
print(alg2.predict(test2)[0])
print(alg2.predict(test3)[0])
# Out:
# True
# True
# False

# %%
print(alg3.predict(test)[0])
print(alg3.predict(test2)[0])
print(alg3.predict(test3)[0])
# Out:
# True
# True
# False

# %%
print(alg4.predict(test)[0])
print(alg4.predict(test2)[0])
print(alg4.predict(test3)[0])
# Out:
# True
# True
# False

# %% [markdown]
# ### Implementando perceptrón

# %%
from sklearn.linear_model import Perceptron

# %%
# Un perceptrón con las siguientes características y deberán entrenarlo
ppn = Perceptron(eta0=0.001)
ppn.fit(X_train, y_train)
# Out:
# Perceptron(alpha=0.0001, class_weight=None, early_stopping=False, eta0=0.001,
#            fit_intercept=True, max_iter=1000, n_iter_no_change=5, n_jobs=None,
#            penalty=None, random_state=0, shuffle=True, tol=0.001,
#            validation_fraction=0.1, verbose=0, warm_start=False)

# %%
# Ahora, debemos hacer la predicción...
y_pred = ppn.predict(X_test)

# %%
y_pred
# Out:
# array([False, False, False,  True, False, False, False, False, False,
#        False,  True, False, False, False,  True,  True,  True, False,
#        False, False, False, False, False, False, False,  True, False,
#        False, False, False,  True, False, False, False,  True, False,
#        False, False, False, False])

# %%
print('Accuracy: %.2f' % accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.68

# %%
ppn.predict(test2)[0]
# Out:
# False

# %% [markdown]
# ### Extender ejercicio para otras categorías usando pokedex_v2

# %%
pkdx = pd.read_csv('pokedex_v2.csv')

# %%
pkdx
# Out:
#       pokedex_number                            Name  ... generation     status
# 0                  1                       Bulbasaur  ...          1     Normal
# 1                  2                         Ivysaur  ...          1     Normal
# 2                  3                        Venusaur  ...          1     Normal
# 3                  3                   Mega Venusaur  ...          1     Normal
# 4                  4                      Charmander  ...          1     Normal
# ...              ...                             ...  ...        ...        ...
# 1023             888     Zacian Hero of Many Battles  ...          8  Legendary
# 1024             889        Zamazenta Crowned Shield  ...          8  Legendary
# 1025             889  Zamazenta Hero of Many Battles  ...          8  Legendary
# 1026             890                       Eternatus  ...          8  Legendary
# 1027             890             Eternatus Eternamax  ...          8  Legendary
#
# [1028 rows x 13 columns]

# %%
result = pd.merge(pokemon, pkdx, on=['Name'])

# %%
result
# Out:
#            Name  Type 1  Type 2  ...  speed  generation     status
# 0     Bulbasaur   Grass  Poison  ...     45           1     Normal
# 1       Ivysaur   Grass  Poison  ...     60           1     Normal
# 2      Venusaur   Grass  Poison  ...     80           1     Normal
# 3    Charmander    Fire     NaN  ...     65           1     Normal
# 4    Charmeleon    Fire     NaN  ...     80           1     Normal
# ..          ...     ...     ...  ...    ...         ...        ...
# 699     Noivern  Flying  Dragon  ...    123           6     Normal
# 700     Xerneas   Fairy     NaN  ...     99           6  Legendary
# 701     Yveltal    Dark  Flying  ...     99           6  Legendary
# 702     Diancie    Rock   Fairy  ...     50           6   Mythical
# 703   Volcanion    Fire   Water  ...     70           6   Mythical
#
# [704 rows x 24 columns]

# %%
result2= result[result.Generation.isin([3, 4])].copy()
result2.drop(['Legendary'], axis = 'columns', inplace = True)

# %%
result2
# Out:
#           Name   Type 1    Type 2  ...  speed  generation         status
# 251    Treecko    Grass       NaN  ...     70           3         Normal
# 252    Grovyle    Grass       NaN  ...     95           3         Normal
# 253   Sceptile    Grass       NaN  ...    120           3         Normal
# 254    Torchic     Fire       NaN  ...     45           3         Normal
# 255  Combusken     Fire  Fighting  ...     55           3         Normal
# ..         ...      ...       ...  ...    ...         ...            ...
# 484  Cresselia  Psychic       NaN  ...     85           4  Sub Legendary
# 485     Phione    Water       NaN  ...     80           4       Mythical
# 486    Manaphy    Water       NaN  ...    100           4       Mythical
# 487    Darkrai     Dark       NaN  ...    125           4       Mythical
# 488     Arceus   Normal       NaN  ...    120           4       Mythical
#
# [238 rows x 23 columns]

# %%
X = result2[['Total', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']]
y = result2['status']

# %%
X
# Out:
#      Total   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 251    310   40      45       35       65       55     70
# 252    405   50      65       45       85       65     95
# 253    530   70      85       65      105       85    120
# 254    310   45      60       40       70       50     45
# 255    405   60      85       60       85       60     55
# ..     ...  ...     ...      ...      ...      ...    ...
# 484    600  120      70      120       75      130     85
# 485    480   80      80       80       80       80     80
# 486    600  100     100      100      100      100    100
# 487    600   70      90       90      135       90    125
# 488    720  120     120      120      120      120    120
#
# [238 rows x 7 columns]

# %%
y
# Out:
# 251           Normal
# 252           Normal
# 253           Normal
# 254           Normal
# 255           Normal
#            ...
# 484    Sub Legendary
# 485         Mythical
# 486         Mythical
# 487         Mythical
# 488         Mythical
# Name: status, Length: 238, dtype: object

# %%
result2.groupby('status').generation.describe()
# Out:
#                count      mean       std  min  25%  50%  75%  max
# status
# Legendary        5.0  3.400000  0.547723  3.0  3.0  3.0  4.0  4.0
# Mythical         5.0  3.800000  0.447214  3.0  4.0  4.0  4.0  4.0
# Normal         217.0  3.423963  0.495327  3.0  3.0  3.0  4.0  4.0
# Sub Legendary   11.0  3.545455  0.522233  3.0  3.0  4.0  4.0  4.0
